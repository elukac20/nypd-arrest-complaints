# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
complaints = pd.read_csv("NYPD_Complaint_Data_Historic_20250530.csv")
# Out:
# /var/folders/0d/v5wf93vd20j3t_d7spp38m5w0000gn/T/ipykernel_11606/2951321283.py:1: DtypeWarning: Columns (0,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   complaints = pd.read_csv("NYPD_Complaint_Data_Historic_20250530.csv")

# %%
arrests = pd.read_csv("NYPD_Arrests_Data__Historic__20250530.csv")

# %%
complaints_sorted = complaints.sort_values(by=['CMPLNT_FR_DT','CMPLNT_FR_TM'])
complaints_sorted
# Out:
#         CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 225067    47950156   01/01/1948     04:00:00   06/28/2008     02:51:00
# 6105718  226616730   01/01/1955     00:01:00   12/31/1957     00:59:00
# 5701972  221569468   01/01/1955     10:00:00   01/01/1967     10:00:00
# 6752812  249596456   01/01/1961     00:00:00   12/31/1961     23:59:00
# 6894159  252593706   01/01/1964     00:01:00          NaN       (null)
# ...            ...          ...          ...          ...          ...
# 2458532   92143870          NaN     23:40:00   08/14/2013     02:00:00
# 8773108   47409515          NaN     23:50:00          NaN       (null)
# 8071409   10987870          NaN     23:54:00   04/11/2006     00:05:00
# 2980677  139772251          NaN     23:55:00   11/21/2014     00:05:00
# 8129642   10883958          NaN     23:55:00          NaN       (null)
#
#          ADDR_PCT_CD      RPT_DT  KY_CD                       OFNS_DESC  \
# 225067         105.0  07/02/2008    361   OFF. AGNST PUB ORD SENSBLTY &
# 6105718        123.0  04/07/2021    116                      SEX CRIMES
# 5701972         62.0  12/09/2020    116                      SEX CRIMES
# 6752812         19.0  08/15/2022    116                      SEX CRIMES
# 6894159         42.0  10/14/2022    116                      SEX CRIMES
# ...              ...         ...    ...                             ...
# 2458532         13.0  08/14/2013    361   OFF. AGNST PUB ORD SENSBLTY &
# 8773108         13.0  06/21/2008    344    ASSAULT 3 & RELATED OFFENSES
# 8071409         73.0  04/11/2006    343  OTHER OFFENSES RELATED TO THEF
# 2980677          7.0  11/21/2014    344    ASSAULT 3 & RELATED OFFENSES
# 8129642        110.0  04/04/2006    344    ASSAULT 3 & RELATED OFFENSES
#
#          PD_CD  ... SUSP_SEX TRANSIT_DISTRICT   Latitude  Longitude  \
# 225067   639.0  ...   (null)              NaN  40.694620 -73.735327
# 6105718  177.0  ...   (null)              NaN  40.512038 -74.249755
# 5701972  177.0  ...        M              NaN  40.602216 -74.002951
# 6752812  177.0  ...   (null)              NaN  40.766996 -73.963922
# 6894159  177.0  ...        M              NaN  40.822271 -73.911698
# ...        ...  ...      ...              ...        ...        ...
# 2458532  639.0  ...        M              NaN  40.738210 -73.992011
# 8773108  113.0  ...   (null)              NaN  40.736698 -73.983316
# 8071409  478.0  ...   (null)              NaN  40.659413 -73.913933
# 2980677  101.0  ...        M              NaN  40.717864 -73.986176
# 8129642  101.0  ...        M              NaN  40.741451 -73.884338
#
#                                        Lat_Lon                PATROL_BORO  \
# 225067                  (40.69462, -73.735327)   PATROL BORO QUEENS SOUTH
# 6105718  (40.5120382535219, -74.2497549524458)  PATROL BORO STATEN ISLAND
# 5701972  (40.6022161657077, -74.0029507988395)    PATROL BORO BKLYN SOUTH
# 6752812  (40.7669956423899, -73.9639223035387)      PATROL BORO MAN NORTH
# 6894159   (40.8222710411331, -73.911697780277)          PATROL BORO BRONX
# ...                                        ...                        ...
# 2458532                 (40.73821, -73.992011)      PATROL BORO MAN SOUTH
# 8773108            (40.73669795, -73.98331594)      PATROL BORO MAN SOUTH
# 8071409                (40.659413, -73.913933)    PATROL BORO BKLYN NORTH
# 2980677                (40.717864, -73.986176)      PATROL BORO MAN SOUTH
# 8129642                (40.741451, -73.884338)   PATROL BORO QUEENS NORTH
#
#         STATION_NAME  VIC_AGE_GROUP        VIC_RACE VIC_SEX
# 225067        (null)          25-44           BLACK       F
# 6105718       (null)            65+           WHITE       F
# 5701972       (null)            65+           WHITE       F
# 6752812       (null)            65+           WHITE       M
# 6894159       (null)          45-64         UNKNOWN       M
# ...              ...            ...             ...     ...
# 2458532       (null)          18-24  WHITE HISPANIC       F
# 8773108       (null)          25-44  WHITE HISPANIC       M
# 8071409       (null)          25-44           WHITE       M
# 2980677       (null)          25-44  WHITE HISPANIC       M
# 8129642       (null)          45-64           WHITE       M
#
# [9491946 rows x 35 columns]

# %%
complaints_sorted['CMPLNT_FR_DT']=pd.to_datetime(complaints_sorted['CMPLNT_FR_DT'], errors='coerce')
complaints_sorted['CMPLNT_FR_DT'].dropna(inplace=True)

# %%
complaints_sorted['CMPLNT_FR_DT']
# Out:
# 225067    1948-01-01
# 6105718   1955-01-01
# 5701972   1955-01-01
# 6752812   1961-01-01
# 6894159   1964-01-01
#              ...
# 2458532          NaT
# 8773108          NaT
# 8071409          NaT
# 2980677          NaT
# 8129642          NaT
# Name: CMPLNT_FR_DT, Length: 9491946, dtype: datetime64[ns]

# %%
morethandate = complaints_sorted['CMPLNT_FR_DT'] >= pd.to_datetime('2006-01-01')

# %%
complaints_subset = complaints_sorted[morethandate]

# %%
complaints_subset['LONGLAT']=complaints_subset['Longitude'].astype(str)+" "+complaints_subset['Latitude'].astype(str)
complaints_subset
# Out:
# /var/folders/0d/v5wf93vd20j3t_d7spp38m5w0000gn/T/ipykernel_11606/751417305.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   complaints_subset['LONGLAT']=complaints_subset['Longitude'].astype(str)+" "+complaints_subset['Latitude'].astype(str)
#         CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 7308      45696867   2006-01-01     00:00:00   12/31/2006     23:59:00
# 83442     46101691   2006-01-01     00:00:00   03/01/2008     15:00:00
# 150747    52275241   2006-01-01     00:00:00   12/31/2007     00:00:00
# 160989    38948518   2006-01-01     00:00:00   12/31/2006     00:00:00
# 169670    52517988   2006-01-01     00:00:00   12/31/2006     00:00:00
# ...            ...          ...          ...          ...          ...
# 9375752  298704253   2024-12-31     23:25:00   12/31/2024     23:30:00
# 9126241  298692886   2024-12-31     23:30:00          NaN       (null)
# 9181203  298703788   2024-12-31     23:30:00   12/31/2024     23:40:00
# 8996177  298704264   2024-12-31     23:37:00   12/31/2024     23:45:00
# 9146670  298712832   2024-12-31     23:45:00   12/31/2024     23:50:00
#
#          ADDR_PCT_CD      RPT_DT  KY_CD          OFNS_DESC  PD_CD  ...  \
# 7308            40.0  04/14/2008    340             FRAUDS  718.0  ...
# 83442           44.0  04/30/2008    112        THEFT-FRAUD  739.0  ...
# 150747          49.0  10/16/2008    340             FRAUDS  718.0  ...
# 160989          49.0  02/05/2008    340             FRAUDS  718.0  ...
# 169670          77.0  10/24/2008    116         SEX CRIMES  179.0  ...
# ...              ...         ...    ...                ...    ...  ...
# 9375752         67.0  12/31/2024    118  DANGEROUS WEAPONS  792.0  ...
# 9126241         13.0  12/31/2024    107           BURGLARY  223.0  ...
# 9181203         47.0  12/31/2024    578      HARRASSMENT 2  637.0  ...
# 8996177         72.0  12/31/2024    106     FELONY ASSAULT  109.0  ...
# 9146670         75.0  12/31/2024    125   OTHER STATE LAWS  847.0  ...
#
#         TRANSIT_DISTRICT   Latitude  Longitude  \
# 7308                 NaN  40.811507 -73.922606
# 83442                NaN  40.838528 -73.915334
# 150747               NaN  40.855565 -73.865718
# 160989               NaN  40.861223 -73.860729
# 169670               NaN  40.674496 -73.930571
# ...                  ...        ...        ...
# 9375752              NaN  40.657858 -73.916488
# 9126241              NaN  40.732922 -73.981277
# 9181203              NaN  40.877125 -73.865602
# 8996177              NaN  40.661646 -73.998435
# 9146670              NaN  40.656262 -73.891081
#
#                                          Lat_Lon              PATROL_BORO  \
# 7308                     (40.811507, -73.922606)        PATROL BORO BRONX
# 83442                    (40.838528, -73.915334)        PATROL BORO BRONX
# 150747                   (40.855565, -73.865718)        PATROL BORO BRONX
# 160989                   (40.861223, -73.860729)        PATROL BORO BRONX
# 169670     (40.6744956865259, -73.9305713255961)  PATROL BORO BKLYN NORTH
# ...                                          ...                      ...
# 9375752  (40.65785843797927, -73.91648767685969)  PATROL BORO BKLYN SOUTH
# 9126241                  (40.732922, -73.981277)    PATROL BORO MAN SOUTH
# 9181203                  (40.877125, -73.865602)        PATROL BORO BRONX
# 8996177                  (40.661646, -73.998435)  PATROL BORO BKLYN SOUTH
# 9146670   (40.65626168022815, -73.8910808434055)  PATROL BORO BKLYN NORTH
#
#         STATION_NAME VIC_AGE_GROUP        VIC_RACE VIC_SEX  \
# 7308          (null)         25-44           BLACK       F
# 83442         (null)         25-44  BLACK HISPANIC       F
# 150747        (null)         25-44         UNKNOWN       M
# 160989        (null)         25-44  WHITE HISPANIC       M
# 169670        (null)           <18           BLACK       F
# ...              ...           ...             ...     ...
# 9375752       (null)       UNKNOWN         UNKNOWN       E
# 9126241       (null)         18-24           WHITE       F
# 9181203       (null)         45-64           BLACK       F
# 8996177       (null)         45-64  WHITE HISPANIC       F
# 9146670       (null)       UNKNOWN         UNKNOWN       E
#
#                                       LONGLAT
# 7308                     -73.922606 40.811507
# 83442                    -73.915334 40.838528
# 150747                   -73.865718 40.855565
# 160989                   -73.860729 40.861223
# 169670     -73.9305713255961 40.6744956865259
# ...                                       ...
# 9375752  -73.91648767685969 40.65785843797927
# 9126241                  -73.981277 40.732922
# 9181203                  -73.865602 40.877125
# 8996177                  -73.998435 40.661646
# 9146670   -73.8910808434055 40.65626168022815
#
# [9470313 rows x 36 columns]

# %%
arrests_sorted = arrests.sort_values(by=['ARREST_DATE'])
arrests_sorted
# Out:
#          ARREST_KEY ARREST_DATE  PD_CD  \
# 5985472     9929805  01/01/2006  793.0
# 5976830     9930311  01/01/2006  750.0
# 5980692     9929897  01/01/2006  779.0
# 5980694     9930087  01/01/2006  567.0
# 5983584     9930095  01/01/2006  101.0
# ...             ...         ...    ...
# 256186    298672654  12/31/2024  793.0
# 255113    298699290  12/31/2024  109.0
# 256145    298663611  12/31/2024  922.0
# 12651     298690452  12/31/2024  105.0
# 253806    298682165  12/31/2024  268.0
#
#                                            PD_DESC  KY_CD  \
# 5985472                       WEAPONS POSSESSION 3  118.0
# 5976830                           RESISTING ARREST  359.0
# 5980692  PUBLIC ADMINISTRATION,UNCLASSIFIED FELONY  126.0
# 5980694                MARIJUANA, POSSESSION 4 & 5  235.0
# 5983584                                  ASSAULT 3  344.0
# ...                                            ...    ...
# 256186                        WEAPONS POSSESSION 3  118.0
# 255113                    ASSAULT 2,1,UNCLASSIFIED  106.0
# 256145              TRAFFIC,UNCLASSIFIED MISDEMEAN  348.0
# 12651                            STRANGULATION 1ST  106.0
# 253806                          CRIMINAL MIS 2 & 3  121.0
#
#                                       OFNS_DESC    LAW_CODE LAW_CAT_CD  \
# 5985472                       DANGEROUS WEAPONS  PL 2650204          F
# 5976830  OFFENSES AGAINST PUBLIC ADMINISTRATION  PL 2053000          M
# 5980692                 MISCELLANEOUS PENAL LAW  PL 215510B          F
# 5980694                         DANGEROUS DRUGS  PL 2211001          M
# 5983584            ASSAULT 3 & RELATED OFFENSES  PL 1200001          M
# ...                                         ...         ...        ...
# 256186                        DANGEROUS WEAPONS  PL 2650201          F
# 255113                           FELONY ASSAULT  PL 1200502          F
# 256145                 VEHICLE AND TRAFFIC LAWS  VTL05110E2          F
# 12651                            FELONY ASSAULT  PL 1211200          F
# 253806           CRIMINAL MISCHIEF & RELATED OF  PL 1450502          F
#
#         ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX  \
# 5985472           B               52                0.0     25-44        M
# 5976830           Q              111                0.0     45-64        M
# 5980692           B               40                0.0     45-64        M
# 5980694           M                7                0.0     25-44        M
# 5983584           M               19                0.0     18-24        M
# ...             ...              ...                ...       ...      ...
# 256186            K               75                2.0     45-64        M
# 255113            Q              102                0.0     45-64        M
# 256145            B               40                0.0     25-44        M
# 12651             B               40                0.0     25-44        M
# 253806            Q              109                0.0     18-24        M
#
#                         PERP_RACE  X_COORD_CD  Y_COORD_CD   Latitude  \
# 5985472            WHITE HISPANIC   1015192.0    257668.0  40.873868
# 5976830  ASIAN / PACIFIC ISLANDER   1046277.0    210432.0  40.744055
# 5980692                     BLACK   1006737.0    233009.0  40.806211
# 5980694                     WHITE    987478.0    201620.0  40.720085
# 5983584                     WHITE    996157.0    222560.0  40.777552
# ...                           ...         ...         ...        ...
# 256186                      BLACK   1019192.0    183434.0  40.670101
# 255113                      WHITE   1031992.0    197141.0  40.707664
# 256145                      BLACK   1003284.0    235725.0  40.813666
# 12651                       BLACK   1009012.0    236134.0  40.814785
# 253806             WHITE HISPANIC   1032084.0    216954.0  40.762045
#
#          Longitude                                        Lon_Lat
# 5985472 -73.888119  POINT (-73.88811877499995 40.873867549000074)
# 5976830 -73.776156   POINT (-73.77615584299997 40.74405453100008)
# 5980692 -73.918774   POINT (-73.91877372999993 40.80621138200007)
# 5980694 -73.988356   POINT (-73.98835630899998 40.72008467900002)
# 5983584 -73.957009   POINT (-73.95700940399996 40.77755228400008)
# ...            ...                                            ...
# 256186  -73.874039                   POINT (-73.874039 40.670101)
# 255113  -73.827801                   POINT (-73.827801 40.707664)
# 256145  -73.931238   POINT (-73.93123754706842 40.81366588249614)
# 12651   -73.910542                   POINT (-73.910542 40.814785)
# 253806  -73.827329                   POINT (-73.827329 40.762045)
#
# [5986025 rows x 19 columns]

# %%
arrests_sorted['ARREST_DATE']=pd.to_datetime(arrests_sorted['ARREST_DATE'], errors='coerce')
arrests_sorted['LONGLAT']=arrests_sorted['Longitude'].astype(str)+" "+arrests_sorted['Latitude'].astype(str)
arrests_sorted
# Out:
#          ARREST_KEY ARREST_DATE  PD_CD  \
# 5985472     9929805  2006-01-01  793.0
# 5976830     9930311  2006-01-01  750.0
# 5980692     9929897  2006-01-01  779.0
# 5980694     9930087  2006-01-01  567.0
# 5983584     9930095  2006-01-01  101.0
# ...             ...         ...    ...
# 256186    298672654  2024-12-31  793.0
# 255113    298699290  2024-12-31  109.0
# 256145    298663611  2024-12-31  922.0
# 12651     298690452  2024-12-31  105.0
# 253806    298682165  2024-12-31  268.0
#
#                                            PD_DESC  KY_CD  \
# 5985472                       WEAPONS POSSESSION 3  118.0
# 5976830                           RESISTING ARREST  359.0
# 5980692  PUBLIC ADMINISTRATION,UNCLASSIFIED FELONY  126.0
# 5980694                MARIJUANA, POSSESSION 4 & 5  235.0
# 5983584                                  ASSAULT 3  344.0
# ...                                            ...    ...
# 256186                        WEAPONS POSSESSION 3  118.0
# 255113                    ASSAULT 2,1,UNCLASSIFIED  106.0
# 256145              TRAFFIC,UNCLASSIFIED MISDEMEAN  348.0
# 12651                            STRANGULATION 1ST  106.0
# 253806                          CRIMINAL MIS 2 & 3  121.0
#
#                                       OFNS_DESC    LAW_CODE LAW_CAT_CD  \
# 5985472                       DANGEROUS WEAPONS  PL 2650204          F
# 5976830  OFFENSES AGAINST PUBLIC ADMINISTRATION  PL 2053000          M
# 5980692                 MISCELLANEOUS PENAL LAW  PL 215510B          F
# 5980694                         DANGEROUS DRUGS  PL 2211001          M
# 5983584            ASSAULT 3 & RELATED OFFENSES  PL 1200001          M
# ...                                         ...         ...        ...
# 256186                        DANGEROUS WEAPONS  PL 2650201          F
# 255113                           FELONY ASSAULT  PL 1200502          F
# 256145                 VEHICLE AND TRAFFIC LAWS  VTL05110E2          F
# 12651                            FELONY ASSAULT  PL 1211200          F
# 253806           CRIMINAL MISCHIEF & RELATED OF  PL 1450502          F
#
#         ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX  \
# 5985472           B               52                0.0     25-44        M
# 5976830           Q              111                0.0     45-64        M
# 5980692           B               40                0.0     45-64        M
# 5980694           M                7                0.0     25-44        M
# 5983584           M               19                0.0     18-24        M
# ...             ...              ...                ...       ...      ...
# 256186            K               75                2.0     45-64        M
# 255113            Q              102                0.0     45-64        M
# 256145            B               40                0.0     25-44        M
# 12651             B               40                0.0     25-44        M
# 253806            Q              109                0.0     18-24        M
#
#                         PERP_RACE  X_COORD_CD  Y_COORD_CD   Latitude  \
# 5985472            WHITE HISPANIC   1015192.0    257668.0  40.873868
# 5976830  ASIAN / PACIFIC ISLANDER   1046277.0    210432.0  40.744055
# 5980692                     BLACK   1006737.0    233009.0  40.806211
# 5980694                     WHITE    987478.0    201620.0  40.720085
# 5983584                     WHITE    996157.0    222560.0  40.777552
# ...                           ...         ...         ...        ...
# 256186                      BLACK   1019192.0    183434.0  40.670101
# 255113                      WHITE   1031992.0    197141.0  40.707664
# 256145                      BLACK   1003284.0    235725.0  40.813666
# 12651                       BLACK   1009012.0    236134.0  40.814785
# 253806             WHITE HISPANIC   1032084.0    216954.0  40.762045
#
#          Longitude                                        Lon_Lat  \
# 5985472 -73.888119  POINT (-73.88811877499995 40.873867549000074)
# 5976830 -73.776156   POINT (-73.77615584299997 40.74405453100008)
# 5980692 -73.918774   POINT (-73.91877372999993 40.80621138200007)
# 5980694 -73.988356   POINT (-73.98835630899998 40.72008467900002)
# 5983584 -73.957009   POINT (-73.95700940399996 40.77755228400008)
# ...            ...                                            ...
# 256186  -73.874039                   POINT (-73.874039 40.670101)
# 255113  -73.827801                   POINT (-73.827801 40.707664)
# 256145  -73.931238   POINT (-73.93123754706842 40.81366588249614)
# 12651   -73.910542                   POINT (-73.910542 40.814785)
# 253806  -73.827329                   POINT (-73.827329 40.762045)
#
#                                        LONGLAT
# 5985472  -73.88811877499995 40.873867549000074
# 5976830   -73.77615584299997 40.74405453100008
# 5980692   -73.91877372999993 40.80621138200007
# 5980694   -73.98835630899998 40.72008467900002
# 5983584   -73.95700940399996 40.77755228400008
# ...                                        ...
# 256186                    -73.874039 40.670101
# 255113                    -73.827801 40.707664
# 256145    -73.93123754706842 40.81366588249614
# 12651                     -73.910542 40.814785
# 253806                    -73.827329 40.762045
#
# [5986025 rows x 20 columns]

# %%
arrests_sorted.columns = arrests_sorted.columns.to_series().replace({'ARREST_DATE':'DATE'})

complaints_subset.columns = complaints_subset.columns.to_series().replace({'CMPLNT_FR_DT':'DATE'})

# %%
complaints_subset
# Out:
#         CMPLNT_NUM       DATE CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 7308      45696867 2006-01-01     00:00:00   12/31/2006     23:59:00
# 83442     46101691 2006-01-01     00:00:00   03/01/2008     15:00:00
# 150747    52275241 2006-01-01     00:00:00   12/31/2007     00:00:00
# 160989    38948518 2006-01-01     00:00:00   12/31/2006     00:00:00
# 169670    52517988 2006-01-01     00:00:00   12/31/2006     00:00:00
# ...            ...        ...          ...          ...          ...
# 9375752  298704253 2024-12-31     23:25:00   12/31/2024     23:30:00
# 9126241  298692886 2024-12-31     23:30:00          NaN       (null)
# 9181203  298703788 2024-12-31     23:30:00   12/31/2024     23:40:00
# 8996177  298704264 2024-12-31     23:37:00   12/31/2024     23:45:00
# 9146670  298712832 2024-12-31     23:45:00   12/31/2024     23:50:00
#
#          ADDR_PCT_CD      RPT_DT  KY_CD          OFNS_DESC  PD_CD  ...  \
# 7308            40.0  04/14/2008    340             FRAUDS  718.0  ...
# 83442           44.0  04/30/2008    112        THEFT-FRAUD  739.0  ...
# 150747          49.0  10/16/2008    340             FRAUDS  718.0  ...
# 160989          49.0  02/05/2008    340             FRAUDS  718.0  ...
# 169670          77.0  10/24/2008    116         SEX CRIMES  179.0  ...
# ...              ...         ...    ...                ...    ...  ...
# 9375752         67.0  12/31/2024    118  DANGEROUS WEAPONS  792.0  ...
# 9126241         13.0  12/31/2024    107           BURGLARY  223.0  ...
# 9181203         47.0  12/31/2024    578      HARRASSMENT 2  637.0  ...
# 8996177         72.0  12/31/2024    106     FELONY ASSAULT  109.0  ...
# 9146670         75.0  12/31/2024    125   OTHER STATE LAWS  847.0  ...
#
#         TRANSIT_DISTRICT   Latitude  Longitude  \
# 7308                 NaN  40.811507 -73.922606
# 83442                NaN  40.838528 -73.915334
# 150747               NaN  40.855565 -73.865718
# 160989               NaN  40.861223 -73.860729
# 169670               NaN  40.674496 -73.930571
# ...                  ...        ...        ...
# 9375752              NaN  40.657858 -73.916488
# 9126241              NaN  40.732922 -73.981277
# 9181203              NaN  40.877125 -73.865602
# 8996177              NaN  40.661646 -73.998435
# 9146670              NaN  40.656262 -73.891081
#
#                                          Lat_Lon              PATROL_BORO  \
# 7308                     (40.811507, -73.922606)        PATROL BORO BRONX
# 83442                    (40.838528, -73.915334)        PATROL BORO BRONX
# 150747                   (40.855565, -73.865718)        PATROL BORO BRONX
# 160989                   (40.861223, -73.860729)        PATROL BORO BRONX
# 169670     (40.6744956865259, -73.9305713255961)  PATROL BORO BKLYN NORTH
# ...                                          ...                      ...
# 9375752  (40.65785843797927, -73.91648767685969)  PATROL BORO BKLYN SOUTH
# 9126241                  (40.732922, -73.981277)    PATROL BORO MAN SOUTH
# 9181203                  (40.877125, -73.865602)        PATROL BORO BRONX
# 8996177                  (40.661646, -73.998435)  PATROL BORO BKLYN SOUTH
# 9146670   (40.65626168022815, -73.8910808434055)  PATROL BORO BKLYN NORTH
#
#         STATION_NAME VIC_AGE_GROUP        VIC_RACE VIC_SEX  \
# 7308          (null)         25-44           BLACK       F
# 83442         (null)         25-44  BLACK HISPANIC       F
# 150747        (null)         25-44         UNKNOWN       M
# 160989        (null)         25-44  WHITE HISPANIC       M
# 169670        (null)           <18           BLACK       F
# ...              ...           ...             ...     ...
# 9375752       (null)       UNKNOWN         UNKNOWN       E
# 9126241       (null)         18-24           WHITE       F
# 9181203       (null)         45-64           BLACK       F
# 8996177       (null)         45-64  WHITE HISPANIC       F
# 9146670       (null)       UNKNOWN         UNKNOWN       E
#
#                                       LONGLAT
# 7308                     -73.922606 40.811507
# 83442                    -73.915334 40.838528
# 150747                   -73.865718 40.855565
# 160989                   -73.860729 40.861223
# 169670     -73.9305713255961 40.6744956865259
# ...                                       ...
# 9375752  -73.91648767685969 40.65785843797927
# 9126241                  -73.981277 40.732922
# 9181203                  -73.865602 40.877125
# 8996177                  -73.998435 40.661646
# 9146670   -73.8910808434055 40.65626168022815
#
# [9470313 rows x 36 columns]

# %% [markdown]
# # Complaints that result in arrests
#
# Using date of the complaint / arrest and the longitude and latitude

# %%
complaints_subset.columns
# Out:
# Index(['CMPLNT_NUM', 'DATE', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT', 'CMPLNT_TO_TM',
#        'ADDR_PCT_CD', 'RPT_DT', 'KY_CD', 'OFNS_DESC', 'PD_CD', 'PD_DESC',
#        'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'BORO_NM', 'LOC_OF_OCCUR_DESC',
#        'PREM_TYP_DESC', 'JURIS_DESC', 'JURISDICTION_CODE', 'PARKS_NM',
#        'HADEVELOPT', 'HOUSING_PSA', 'X_COORD_CD', 'Y_COORD_CD',
#        'SUSP_AGE_GROUP', 'SUSP_RACE', 'SUSP_SEX', 'TRANSIT_DISTRICT',
#        'Latitude', 'Longitude', 'Lat_Lon', 'PATROL_BORO', 'STATION_NAME',
#        'VIC_AGE_GROUP', 'VIC_RACE', 'VIC_SEX', 'LONGLAT'],
#       dtype='object')

# %%
arrest_complaints = pd.merge(arrests_sorted, complaints_subset, on=['DATE','LONGLAT'], how='inner')

# %%
arrest_complaints
# Out:
#         ARREST_KEY       DATE  PD_CD_x                       PD_DESC_x  \
# 0        238513925 2022-01-01    101.0                       ASSAULT 3
# 1        238513925 2022-01-01    101.0                       ASSAULT 3
# 2        238513925 2022-01-01    101.0                       ASSAULT 3
# 3        238513921 2022-01-01    101.0                       ASSAULT 3
# 4        238513921 2022-01-01    101.0                       ASSAULT 3
# ...            ...        ...      ...                             ...
# 666451   298706301 2024-12-31    101.0                       ASSAULT 3
# 666452   298682157 2024-12-31    759.0  PUBLIC ADMINISTATION,UNCLASS M
# 666453   298672654 2024-12-31    793.0            WEAPONS POSSESSION 3
# 666454   298699290 2024-12-31    109.0        ASSAULT 2,1,UNCLASSIFIED
# 666455   298663611 2024-12-31    922.0  TRAFFIC,UNCLASSIFIED MISDEMEAN
#
#         KY_CD_x                     OFNS_DESC_x    LAW_CODE LAW_CAT_CD_x  \
# 0         344.0    ASSAULT 3 & RELATED OFFENSES  PL 1200001            M
# 1         344.0    ASSAULT 3 & RELATED OFFENSES  PL 1200001            M
# 2         344.0    ASSAULT 3 & RELATED OFFENSES  PL 1200001            M
# 3         344.0    ASSAULT 3 & RELATED OFFENSES  PL 1200001            M
# 4         344.0    ASSAULT 3 & RELATED OFFENSES  PL 1200001            M
# ...         ...                             ...         ...          ...
# 666451    344.0    ASSAULT 3 & RELATED OFFENSES  PL 1200001            M
# 666452    359.0  OFFENSES AGAINST PUBLIC ADMINI  PL 1950500            M
# 666453    118.0               DANGEROUS WEAPONS  PL 2650201            F
# 666454    106.0                  FELONY ASSAULT  PL 1200502            F
# 666455    348.0        VEHICLE AND TRAFFIC LAWS  VTL05110E2            F
#
#        ARREST_BORO  ARREST_PRECINCT  ...  SUSP_SEX TRANSIT_DISTRICT  \
# 0                Q              115  ...         M              NaN
# 1                Q              115  ...         M              NaN
# 2                Q              115  ...         M              NaN
# 3                Q              115  ...         M              NaN
# 4                Q              115  ...         M              NaN
# ...            ...              ...  ...       ...              ...
# 666451           M               14  ...         M              NaN
# 666452           K               78  ...         F              NaN
# 666453           K               75  ...         M              NaN
# 666454           Q              102  ...         M              NaN
# 666455           B               40  ...         M              NaN
#
#        Latitude_y Longitude_y                                  Lat_Lon  \
# 0       40.751091  -73.860642                  (40.751091, -73.860642)
# 1       40.751091  -73.860642                  (40.751091, -73.860642)
# 2       40.751091  -73.860642                  (40.751091, -73.860642)
# 3       40.751091  -73.860642                  (40.751091, -73.860642)
# 4       40.751091  -73.860642                  (40.751091, -73.860642)
# ...           ...         ...                                      ...
# 666451  40.753826  -73.980643                  (40.753826, -73.980643)
# 666452  40.668146  -73.978894                  (40.668146, -73.978894)
# 666453  40.670101  -73.874039                  (40.670101, -73.874039)
# 666454  40.707664  -73.827801                  (40.707664, -73.827801)
# 666455  40.813666  -73.931238  (40.81366588249614, -73.93123754706842)
#
#                      PATROL_BORO  STATION_NAME  VIC_AGE_GROUP        VIC_RACE  \
# 0       PATROL BORO QUEENS NORTH        (null)          25-44  WHITE HISPANIC
# 1       PATROL BORO QUEENS NORTH        (null)          25-44  WHITE HISPANIC
# 2       PATROL BORO QUEENS NORTH        (null)          25-44  WHITE HISPANIC
# 3       PATROL BORO QUEENS NORTH        (null)          25-44  WHITE HISPANIC
# 4       PATROL BORO QUEENS NORTH        (null)          25-44  WHITE HISPANIC
# ...                          ...           ...            ...             ...
# 666451     PATROL BORO MAN SOUTH        (null)          25-44  BLACK HISPANIC
# 666452   PATROL BORO BKLYN SOUTH        (null)          18-24           BLACK
# 666453   PATROL BORO BKLYN NORTH        (null)          18-24           BLACK
# 666454  PATROL BORO QUEENS SOUTH        (null)          45-64           WHITE
# 666455         PATROL BORO BRONX        (null)        UNKNOWN         UNKNOWN
#
#        VIC_SEX
# 0            M
# 1            M
# 2            M
# 3            M
# 4            M
# ...        ...
# 666451       M
# 666452       M
# 666453       F
# 666454       M
# 666455       E
#
# [666456 rows x 54 columns]

# %%
len(complaints)
# Out:
# 9491946

# %%
len(arrest_complaints)
# Out:
# 666456
